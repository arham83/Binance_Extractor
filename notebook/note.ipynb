# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/Users/Arham Riaz/MBZUAI/Code/Binance_Extractor/BTCUSDT-aggTrades-2026-08.csv')

# View the first 5 rows
print(df.head())
# Out:
#    agg_trade_id    price  quantity  first_trade_id  last_trade_id  \
# 0    3399378200  62859.8     0.002      7945224454     7945224455
# 1    3399378201  62859.9     0.001      7945224456     7945224456
# 2    3399378202  62859.9     0.010      7945224457     7945224458
# 3    3399378203  62859.8     0.044      7945224459     7945224461
# 4    3399378204  62859.8     0.237      7945224462     7945224462
#
#    transact_time  is_buyer_maker
# 0  1785542400081            True
# 1  1785542400163           False
# 2  1785542400290           False
# 3  1785542400537            True
# 4  1785542400660            True

# %%
df.shape[0]
# Out:
# 35676321
