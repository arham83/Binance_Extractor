# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_parquet('/Users/Arham Riaz/MBZUAI/Code/Binance_Extractor/data/features/market_128_by_symbol/BTCUSDT-features.parquet')

# View the first 5 rows
print(df.shape)
# Out:
# (2979360, 130)

# %%
df.columns.tolist()
# Out:
# ['candle_end_utc',
#  'symbol',
#  'log_return_1',
#  'log_return_2',
#  'log_return_3',
#  'log_return_5',
#  'log_return_10',
#  'log_return_20',
#  'log_return_40',
#  'log_return_80',
#  'candle_body',
#  'candle_range',
#  'upper_wick',
#  'lower_wick',
#  'ema_distance_5',
#  'ema_distance_10',
#  'ema_distance_20',
#  'ema_distance_40',
#  'ema_distance_80',
#  'ema_distance_160',
#  'sma_distance_10',
#  'sma_distance_20',
#  'sma_distance_50',
#  'sma_distance_100',
#  'log_slope_10',
#  'log_slope_20',
#  'log_slope_40',
#  'log_slope_80',
#  'log_slope_160',
#  'log_r2_10',
#  'log_r2_20',
#  'log_r2_40',
#  'log_r2_80',
#  'log_r2_160',
#  'rsi_5',
#  'rsi_7',
#  'rsi_14',
#  'rsi_21',
#  'rsi_28',
#  'rsi_42',
#  'stoch_k_7',
#  'stoch_d_7',
#  'stoch_k_14',
#  'stoch_d_14',
#  'stoch_k_21',
#  'stoch_d_21',
#  'stoch_k_28',
#  'stoch_d_28',
#  'cci_10',
#  'cci_20',
#  'cci_40',
#  'cci_80',
#  'macd_line_6_13_5',
#  'macd_hist_6_13_5',
#  'macd_line_12_26_9',
# ...
